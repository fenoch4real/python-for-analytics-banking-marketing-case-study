# %% [markdown]
# ## MSCA 37014  Python for Analytics
# ### Assignment#1 Supervised Learning Regression (125 points + 10 bonus points)
# ### Exploratory Data Analysis, Data Preprocessing, Simple and Multiple Linear Regression Model
# ### Due Date: 3/4/2020
# Please submit your assignment solutions in **PDF** or **HTML** file; **Submitted Jupyter Notebook will not be graded**
#
# ***
#
# In this assignment, please use Boston Housing Data (a set of features that describe a house in Boston) and the Linear Regression to train the machine learning model to predict the house price. You can find the Boston Housing Data in csv file in the updated Data folder I recently have shared. In this dataset, each row describes a boston town or suburb. There are 506 rows and 13 attributes (features) with a target column named as medv (price).
#
# ### Part 1 - Exploratory Data Analysis and Data Visualization (45 points + 10 bonus points)
#
# #### 1. Import Libraries and load the data into the pandas data frame (5 points)
# #### 2. Review data dimension and data type for each feature in the dataset (5 points)
# #### 3. Identify the unique number of values of each feature in the dataset (5 points)
# #### 4. Check for missing values in the dataset (5 points)
# #### 5. Review the data summary statistics (5 points)
# #### 6. Create a correlation table with all the numeric features (5 points)
# #### 7. Plot a heatmap based on the correlation table from 7 (5 points)
# #### 8. Create some simple and quick plots with all the feature (hint: pairplot()) (5 points)
# #### 9. Create additional plots which could discover and support the key data findings for Part 1 (5 bonus points)
# #### 10. Make a Data Summary from Exploratory Data Analysis and Data Visualization for Part 1 (5 points + 5 bonus points)
# - 1) What are the features which are highly correlated to the target variable (MEDV)? (5 points)
# - 2) What additional data insights you think are valuable to share.(5 bonus points)
#
#
# ### Part 2 - Simple Linear Regression (only use one feature having the highest correlation coefficient with the target variable) (45 points)
#
# #### 1. Split the dataset into X, y, Training set, and Test set (only the highly correlated feature in X) (5 points)
# #### 2. Train the Simple Linear Regression model on the Training set (10 points)
# #### 3. Predict and visualize the test set results (10 points)
# #### 4. Visualize the training set results (5 points)
# #### 5. Make a single prediction (5 points)
# #### 6. Get the final linear regression equation (with values of the coefficients) (10 points)
#
#
# ### Part 3 - Multiple Linear Regression (35 points)
#
# #### 1. Split the dataset into X, y, Training set, and Test set (more than one feature in X) (5 points)
# #### 2. Train the Multiple Linear Regression model on the Training set (10 points)
# #### 3. Predict the test set results (5 points)
# #### 4. Make a single prediction (5 points)
# #### 5. Get the final linear regression equation (with values of the coefficients) (10 points)

# %% [markdown]
# ### Boston Data Description
#
# - The medv variable is the **target variable**.
#
# - The Boston data frame has 506 rows and 13 columns.
#
# - This data frame contains the following columns:
#
# `crim`: per capita crime rate by town.
#
# `zn`: proportion of residential land zoned for lots over 25,000 sq.ft.
#
# `indus`: proportion of non-retail business acres per town.
#
# `chas`: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
# `nox`: nitrogen oxides concentration (parts per 10 million).
#
# `rm`: average number of rooms per dwelling.
#
# `age`: proportion of owner-occupied units built prior to 1940.
#
# `dis`: weighted mean of distances to five Boston employment centres.
#
# `rad`: index of accessibility to radial highways.
#
# `tax`: full-value property-tax rate per \$10,000.
#
# `ptratio`: pupil-teacher ratio by town.
#
# `lstat`: lower status of the population (percent).
#
# `medv`: median value of owner-occupied homes in \$1000s.
#
#
# #### Source
#
# Harrison, D. and Rubinfeld, D.L. (1978) Hedonic prices and the demand for clean air. J. Environ. Economics and Management 5, 81–102.
#
# Belsley D.A., Kuh, E. and Welsch, R.E. (1980) Regression Diagnostics. Identifying Influential Data and Sources of Collinearity. New York: Wiley.
#
# ***
# ***

# %% [markdown]
# ## Part 1 - Exploratory Data Analysis and Data Visualization
#
# ### 1. Import Libraries and oad the data into the pandas data frame

# %%
# Student's Answer: 
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### 2. Review data dimension and data type for each feature

# %%
# Student's Answer: 
dataset = pd.read_csv('BostonHousingData.csv', sep=',')
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  LSTAT    506 non-null    float64
#  12  MEDV     506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 51.5 KB

# %%
dataset.head(3)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
#
#    LSTAT  MEDV
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7

# %% [markdown]
# ### 3. Identify the unique number of values of each feature in the dataset

# %%
# Student's Answer:
dataset['CRIM'].value_counts()
# Out:
# 14.33370    2
# 0.01501     2
# 0.08265     1
# 1.35472     1
# 0.03615     1
#            ..
# 0.11460     1
# 0.03237     1
# 5.82115     1
# 0.02187     1
# 0.03578     1
# Name: CRIM, Length: 504, dtype: int64

# %%
dataset['ZN'].value_counts()
# Out:
# 0.0      372
# 20.0      21
# 80.0      15
# 12.5      10
# 22.0      10
# 25.0      10
# 40.0       7
# 45.0       6
# 30.0       6
# 90.0       5
# 21.0       4
# 95.0       4
# 60.0       4
# 33.0       4
# 75.0       3
# 35.0       3
# 28.0       3
# 55.0       3
# 52.5       3
# 70.0       3
# 34.0       3
# 85.0       2
# 82.5       2
# 17.5       1
# 100.0      1
# 18.0       1
# Name: ZN, dtype: int64

# %%
dataset['INDUS'].value_counts()
# Out:
# 18.10    132
# 19.58     30
# 8.14      22
# 6.20      18
# 21.89     15
#         ...
# 1.21       1
# 4.15       1
# 2.02       1
# 2.01       1
# 4.00       1
# Name: INDUS, Length: 76, dtype: int64

# %%
dataset['CHAS'].value_counts()
# Out:
# 0    471
# 1     35
# Name: CHAS, dtype: int64

# %%
dataset['NOX'].value_counts()
# Out:
# 0.538    23
# 0.713    18
# 0.437    17
# 0.871    16
# 0.624    15
#          ..
# 0.435     1
# 0.422     1
# 0.518     1
# 0.385     1
# 0.389     1
# Name: NOX, Length: 81, dtype: int64

# %%
dataset['RM'].value_counts()
# Out:
# 6.405    3
# 5.713    3
# 6.167    3
# 6.127    3
# 6.229    3
#         ..
# 6.701    1
# 6.232    1
# 6.593    1
# 6.800    1
# 6.625    1
# Name: RM, Length: 446, dtype: int64

# %%
dataset['AGE'].value_counts()
# Out:
# 100.0    43
# 96.0      4
# 98.2      4
# 95.4      4
# 97.9      4
#          ..
# 47.6      1
# 92.7      1
# 13.9      1
# 58.4      1
# 40.1      1
# Name: AGE, Length: 356, dtype: int64

# %%
dataset['DIS'].value_counts()
# Out:
# 3.4952    5
# 5.2873    4
# 5.4007    4
# 5.7209    4
# 6.8147    4
#          ..
# 1.7659    1
# 4.4534    1
# 2.1000    1
# 4.0905    1
# 1.8125    1
# Name: DIS, Length: 412, dtype: int64

# %%
dataset['RAD'].value_counts()
# Out:
# 24    132
# 5     115
# 4     110
# 3      38
# 6      26
# 8      24
# 2      24
# 1      20
# 7      17
# Name: RAD, dtype: int64

# %%
dataset['TAX'].value_counts()
# Out:
# 666    132
# 307     40
# 403     30
# 437     15
# 304     14
#       ...
# 280      1
# 313      1
# 351      1
# 422      1
# 285      1
# Name: TAX, Length: 66, dtype: int64

# %%
dataset['PTRATIO'].value_counts()
# Out:
# 20.2    140
# 14.7     34
# 21.0     27
# 17.8     23
# 19.2     19
# 17.4     18
# 18.6     17
# 19.1     17
# 16.6     16
# 18.4     16
# 21.2     15
# 15.2     13
# 13.0     12
# 20.9     11
# 17.9     11
# 18.7      9
# 19.7      8
# 19.6      8
# 17.6      7
# 16.4      6
# 18.0      5
# 16.0      5
# 20.1      5
# 16.1      5
# 16.9      5
# 16.8      4
# 14.9      4
# 19.0      4
# 18.5      4
# 17.0      4
# 18.2      4
# 18.3      4
# 12.6      3
# 14.8      3
# 18.9      3
# 15.3      3
# 15.9      2
# 22.0      2
# 15.6      2
# 18.8      2
# 15.5      1
# 17.3      1
# 15.1      1
# 21.1      1
# 13.6      1
# 14.4      1
# Name: PTRATIO, dtype: int64

# %%
dataset['LSTAT'].value_counts()
# Out:
# 14.10    3
# 6.36     3
# 18.13    3
# 8.05     3
# 7.79     3
#         ..
# 9.69     1
# 9.62     1
# 5.64     1
# 22.98    1
# 29.05    1
# Name: LSTAT, Length: 455, dtype: int64

# %%
dataset['MEDV'].value_counts()
# Out:
# 50.0    16
# 25.0     8
# 23.1     7
# 21.7     7
# 22.0     7
#         ..
# 12.8     1
# 29.9     1
# 9.6      1
# 36.1     1
# 13.0     1
# Name: MEDV, Length: 229, dtype: int64

# %% [markdown]
# ### 4. Check for missing values

# %%
# Student's Answer: 
dataset.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# ### 5. Review the data summary statistics

# %%
# Student's Answer:
dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO       LSTAT  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# std     28.148861    2.105710    8.707259  168.537116    2.164946    7.141062
# min      2.900000    1.129600    1.000000  187.000000   12.600000    1.730000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000    6.950000
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000   11.360000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000   16.955000
# max    100.000000   12.126500   24.000000  711.000000   22.000000   37.970000
#
#              MEDV
# count  506.000000
# mean    22.532806
# std      9.197104
# min      5.000000
# 25%     17.025000
# 50%     21.200000
# 75%     25.000000
# max     50.000000

# %% [markdown]
# ### 6. Create a correlation table with all the numeric features

# %%
# Student's Answer: 
dataset.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# LSTAT    0.455621 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# MEDV    -0.388305  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO     LSTAT      MEDV
# CRIM    -0.379670  0.625505  0.582764  0.289946  0.455621 -0.388305
# ZN       0.664408 -0.311948 -0.314563 -0.391679 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000  0.374044 -0.507787
# LSTAT   -0.496996  0.488676  0.543993  0.374044  1.000000 -0.737663
# MEDV     0.249929 -0.381626 -0.468536 -0.507787 -0.737663  1.000000

# %% [markdown]
# ### 7. Plot a heatmap based on the correlation table from 7

# %%
# Student's Answer: 
sns.set(rc={'figure.figsize':(18,8)})
sns.heatmap(dataset.corr(),cmap='coolwarm',annot=True)
plt.show()

# %% [markdown]
# ### 8. Create some simple and quick plots with all the feature (hint: `pairplot()`)

# %%
# Student's Answer:
sns.pairplot(dataset[['LSTAT','RM','PTRATIO']])
plt.show()

# %% [markdown]
# ### 9. Create additional plots which could discover and support the key data findings for Part 1

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  LSTAT    506 non-null    float64
#  12  MEDV     506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 51.5 KB

# %%
sns.jointplot(x='LSTAT',y='MEDV',data=dataset,kind='scatter')
plt.show()

# %%
sns.jointplot(x='DIS',y='MEDV',data=dataset,kind='scatter')
plt.show()

# %%
sns.jointplot(x='AGE',y='MEDV',data=dataset,kind='scatter')
plt.show()

# %%
sns.jointplot(x='RM',y='MEDV',data=dataset,kind='scatter')
plt.show()

# %%
sns.jointplot(x='NOX',y='MEDV',data=dataset,kind='scatter')
plt.show()

# %%
sns.jointplot(x='CHAS',y='MEDV',data=dataset,kind='scatter')
plt.show()

# %% [markdown]
# ### 10. Make a Data Summary from Exploratory Data Analysis and Data Visualization
#
# - 1) What are the features which are highly correlated to the target variable (MEDV)? (5 points)
# - 2) What additional data insights you think are valuable to share.(5 bonus points)

# %%
# Student's Answer:

## 1 -  LSTAT, RM, PTRATIO  - Corrolation greater than 0.5

# %%
## 2 -  Column CHAS very low correlation so taking it out to reduce noise

# %%
clean_dataset = dataset

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt

# Create scaler: scaler
scaler = StandardScaler()

# Create a PCA instance: pca
pca = PCA()

# Create pipeline: pipeline
pipeline = make_pipeline(scaler, pca)

# Fit the pipeline to 'samples'
pipeline.fit(dataset.drop(['MEDV'], axis=1))

# Plot the explained variances
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.xticks(features)
plt.show()

# %% [markdown]
# ## Part 2 - Simple Linear Regression (use the feature having the highest correlation coefficient with the target variable)
# ### 1. Split the dataset into X, y, Training set, and Test set (ony one feature in X)

# %%
# Student's Answer:
#X = dataset.iloc[:, 11].values
#y = dataset.iloc[:, -1].values

X = dataset['LSTAT'].values.reshape(-1, 1)
y = dataset['MEDV'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %% [markdown]
# ### 2. Train the Simple Linear Regression model on the Training set

# %%
# Student's Answer:
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 3. Predict and visualize the test set results

# %%
# Student's Answer:
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 5.347293504416108
# MSE: 53.98802017490144
# RMSE: 7.347654059283238

# %%
from sklearn.metrics import r2_score
r2_score(y_test, predictions)
# Out:
# 0.518785592947577

# %% [markdown]
# ### 4. Visualize the training set results

# %%
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, lm.predict(X_train), color = 'blue')
plt.title('One Predictor - Bank Housing Data')
plt.xlabel('LSTAT')
plt.ylabel('MEDV')
plt.show()

# %% [markdown]
# ### 5. Make a single prediction

# %%
# Student's Answer:
pred_data = [0.21124, 12.5, 7.87, 0.524, 5.631, 100, 6.0821, 5, 311, 15.2, 29.93]
pred_data = np.array(pred_data).reshape(-1,1)

# %%
print(lm.predict(pred_data))
# Out:
# [  34.19434127   22.46254878   26.88270176   33.89575659   29.02022283
#   -61.07165998   28.58956819   29.62262381 -262.50843766   19.88492176
#     5.82253439]

# %% [markdown]
# ### 6. Get the final linear regression equation (with values of the coefficients)

# %%
print(lm2.coef_)
# Out:
# [-0.95467667]

# %%
print(lm2.intercept_)
# Out:
# 34.39600716924934

# %%
from sklearn.metrics import r2_score
r2_score(y_test, predictions)
# Out:
# 0.518785592947577

# %% [markdown]
# # Student's Answer:
# ###### MEDV = 34 + -0.95xLSTAT

# %% [markdown]
# ## Part 3 - Multiple Linear Regression
# ### 1. Split the dataset into X, y, Training set, and Test set (more than one feature in X)

# %%
# Student's Answer:
clean_dataset = clean_dataset.drop(['CHAS'], axis=1)
X,y = clean_dataset.drop(['MEDV'], axis=1), dataset['MEDV']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %% [markdown]
# ### 2. Train the Multiple Linear Regression model on the Training set

# %%
# Student's Answer:
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### 3. Predict the test set results

# %%
# Student's Answer:
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 3.8617968250202397
# MSE: 29.037446620429304
# RMSE: 5.3886405169049185

# %% [markdown]
# ### 4. Make a single prediction

# %%
# Student's Answer:
print(lm.predict([[0.21124, 12.5, 7.87, 0.524, 5.631, 100, 6.0821, 5, 311, 15.2, 29.93]]))
# Out:
# [10.68594548]

# %%
#Coefficient
print(lm.coef_)
# Out:
# [-1.01756193e-01  4.82942385e-02  4.77623813e-02 -1.85020061e+01
#   3.18516572e+00  2.02056930e-02 -1.40297854e+00  2.77632985e-01
#  -1.22015488e-02 -1.01479338e+00 -6.39618750e-01]

# %%
#Intercept
print(lm.intercept_)
# Out:
# 44.97490739924763

# %% [markdown]
# ### 5. Get the final linear regression equation (with values of the coefficients)

# %% [markdown]
# # Student's Answer:
# ###### MEDV = 44 + -1xCRIM + 4xZN + 4xINDUS + -1xNOX + 3xRM + 2xAGE + -1xDIS + 2xRAD + -1xTAX + -1xPTRATIO + -6xLSTAT

# %% [markdown]
# ## Great Job! :)
